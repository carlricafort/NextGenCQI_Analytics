# %% [markdown]
# # This program is dedicated for NextGenCQI Data Analytics using Question Answering
# ## This is for the Lecture Subject
# Note: On this part, no AI is implemented since the library mentioned below suffice the whole functionality of the analytics part.

# %%
import pandas as pd

df = pd.read_csv('Mock Data/Mock Data Lec 4.csv')
df.drop(columns = ["Unnamed: 13"], inplace=True)
df.head() # Does not need to be shown on the website. This is just for an easier visualization of what's happening.
# Out:
# c:\Users\User\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\User\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
#    NUMBER  Last Name Middle Name First Name  Student Number  PRELIM GRADE  \
# 0       1     Santos       Reyes       Juan        20230001         58.12
# 1       2  Dela Cruz     Mendoza      Maria        20230002         43.78
# 2       3     Garcia      Torres       Jose        20230003         69.55
# 3       4  Rodriguez       Lopez        Ana        20230004         14.22
# 4       5  Hernandez       Ramos     Miguel        20230005          5.55
#
#    MIDTERM GRADE  FINAL GRADE  COMPREHENSIVE EXAM 1-25  \
# ...

# %% [markdown]
# ## Data Analytics for Preliminary Grades

# %%
# Create lists for each range
prelim_range1 = [] # 5.00 (Below 75) – Failed
prelim_range2 = [] # 3.00 (75–77) – Passed
prelim_range3 = [] # 2.75 (78–80) – Fair Performance
prelim_range4 = [] # 2.50 (81–83) – Satisfactory Performance
prelim_range5 = [] # 2.25 (84–86) – Low Average Performance
prelim_range6 = [] # 2.00 (87–89) – Average Performance
prelim_range7 = [] # 1.75 (90–92) – High Average Performance
prelim_range8 = [] # 1.50 (93–95) – Superior Performance
prelim_range9 = [] # 1.25 (96–98) – Very Superior Performance
prelim_range10 = [] # 1.00 (99–100) – Excellent Performance

# Categorization loop
for grade in df['PRELIM GRADE']:
    if grade <= 74 :
        prelim_range1.append(grade)
    elif 75 <= grade <= 77:
        prelim_range2.append(grade)
    elif 77 < grade <= 80:
        prelim_range3.append(grade)
    elif 80 < grade <= 83:
        prelim_range4.append(grade)
    elif 83 < grade <= 86:
        prelim_range5.append(grade)
    elif 86 < grade <= 89:
        prelim_range6.append(grade)
    elif 90 < grade <= 92:
        prelim_range7.append(grade)
    elif 93 < grade <= 95:
        prelim_range8.append(grade)
    elif 96 < grade <= 98:
        prelim_range9.append(grade)
    elif 98 < grade <= 100:
        prelim_range10.append(grade)
    
# Count students in each range
count1_range1 = len(prelim_range1) # Counting the number of students for this score range 
count1_range2 = len(prelim_range2) # Counting the number of students for this score range
count1_range3 = len(prelim_range3) # Counting the number of students for this score range 
count1_range4 = len(prelim_range4) # Counting the number of students for this score range 
count1_range5 = len(prelim_range5) # Counting the number of students for this score range
count1_range6 = len(prelim_range6) # Counting the number of students for this score range 
count1_range7 = len(prelim_range7) # Counting the number of students for this score range 
count1_range8 = len(prelim_range8) # Counting the number of students for this score range 
count1_range9 = len(prelim_range9) # Counting the number of students for this score range 
count1_range10 = len(prelim_range10) # Counting the number of students for this score range 

result1 = f"""With the total of {count1_range1} students in the grade range of 5.00 means a failure to meet the minimum requirements of the CLOs. 
This reflects major academic issues possibly due to lack of student motivation, ineffective learning strategies, curriculum misalignment, or faculty instructional gaps. 
A comprehensive review of teaching strategies, curriculum design, student engagement practices, and academic policies is necessary. 
Additional support systems like tutoring, counseling, and motivational workshops should be institutionalized.  """

result2 = f"""Having a total of {count1_range2} students, grades of 75-77 (3.00) range mean students have barely passed and have significant deficiencies in achieving full CLOs. 
This raises concerns about student preparedness for more advanced courses. It is essential to revisit course prerequisites, strengthen early semester interventions, and provide compulsory remedial sessions for students in this range. 
Faculty development programs focusing on differentiated instruction are also suggested."""

result3 = f"""A total of {count1_range3} students obtained scores within the 78–80 (2.75) range are at a fair level, barely above passing thresholds. 
This reflects deficiencies in critical areas such as problem-solving, comprehension, and retention. Faculty should increase diagnostic assessments and offer remedial modules to prevent students from slipping into failing performance. 
Regular mentoring, personalized feedback, and smaller group tutorials could make significant improvements. """

result4 = f"""A total of {count1_range4} students is within the range of 81-83 (2.50). Hence, a grade of 2.50 indicates satisfactory performance, yet students are barely meeting expectations. This suggests minimal CLO attainment at acceptable levels. 
Faculty should enhance engagement strategies such as gamified quizzes, blended learning, and formative assessment to reinforce learning. It is critical to identify struggling students early and offer academic support interventions."""

result5 = f"""The {count1_range5} students within the range of 84-86 (2.25) show a low average performance, signaling potential struggles with understanding more complex topics or maintaining consistent study habits. This suggests that faculty must assess whether the content delivery pace is appropriate and whether differentiated instruction is necessary. 
Mid-course interventions, learning support programs, and targeted tutorials should be strengthened. """

result6 = f"""The {count1_range6} students within the range of 87-89 (2.00) reflects average attainment of the CLOs. Students demonstrate basic competency but are inconsistent in advanced applications. This suggests a need for reinforcing foundational concepts and providing additional support for problem-solving and communication skills. 
Faculty might integrate more scaffolded activities and provide feedback loops to build confidence and mastery. """

result7 = f"""With the total of {count1_range7} number of students obtained scores within the range of 90-92 (1.75) indicates a high average level of performance, meeting most expectations but with room for improving critical thinking and depth of understanding. 
This points toward a need for refining teaching methods to focus more on evaluation, synthesis, and creation stages of Bloom’s Taxonomy. 
More collaborative learning, debates, and reflective assignments are recommended. """

result8 = f"""A total of {count1_range8} students got scores within the range of 93-95 (1.50) showing superior mastery but may indicate slight inconsistencies in applying higher-order thinking. This suggests that while foundational knowledge is solid, application and integration in real-world settings can still be enhanced. 
Faculty should consider increasing authentic assessments (case studies, simulations) and strengthen analytical skills through complex problem-solving activities. """

result9 = f"""{count1_range9} students achieving scores within the range of 96-98 (1.25) reflect very superior performance, demonstrating deep understanding but with minimal learning gaps. This suggests strong alignment between assessment and instruction. To maximize their potential, activities promoting creativity, innovation, and leadership in technical fields should be encouraged. 
Faculty could introduce interdisciplinary projects or student-led seminars to deepen learning further. """

result10 = f"""The {count1_range10} students within the range of 99-100 (1.00) indicate excellent mastery of the Course Learning Outcomes (CLOs). This suggests that instructional strategies, curriculum design, and student engagement are highly effective. 
Minimal to no curriculum adjustments are needed. However, to further challenge students and sustain motivation, introducing research activities, industry immersion, or advanced project-based learning would be beneficial. 
Faculty may also explore mentorship programs for continuous excellence. """


# Finding which range has the highest number of students
highest_range = max(count1_range1, count1_range2, count1_range3, count1_range4, count1_range5, count1_range6, count1_range7, count1_range8, count1_range9, count1_range10)

# Determine the corresponding range
if highest_range == count1_range1:
    print(result1)

elif highest_range == count1_range2:
    print(result2)

elif highest_range == count1_range3:
    print(result3)

elif highest_range == count1_range4:
    print(result4)

elif highest_range == count1_range5:
    print(result5)

elif highest_range == count1_range6:
    print(result6)

elif highest_range == count1_range7:
    print(result7)

elif highest_range == count1_range8:
    print(result8)

elif highest_range == count1_range9:
    print(result9)

elif highest_range == count1_range10:
    print(result10)
# Out:
# With the total of 23 students in the grade range of 5.00 means a failure to meet the minimum requirements of the CLOs.
# This reflects major academic issues possibly due to lack of student motivation, ineffective learning strategies, curriculum misalignment, or faculty instructional gaps.
# A comprehensive review of teaching strategies, curriculum design, student engagement practices, and academic policies is necessary.
# Additional support systems like tutoring, counseling, and motivational workshops should be institutionalized.

# %% [markdown]
# ## Data Analytics for Midterm Grades

# %%
# Create lists for each range
midterm_range1 = [] # 5.00 (Below 75) – Failed
midterm_range2 = [] # 3.00 (75–77) – Passed
midterm_range3 = [] # 2.75 (78–80) – Fair Performance
midterm_range4 = [] # 2.50 (81–83) – Satisfactory Performance
midterm_range5 = [] # 2.25 (84–86) – Low Average Performance
midterm_range6 = [] # 2.00 (87–89) – Average Performance
midterm_range7 = [] # 1.75 (90–92) – High Average Performance
midterm_range8 = [] # 1.50 (93–95) – Superior Performance
midterm_range9 = [] # 1.25 (96–98) – Very Superior Performance
midterm_range10 = [] # 1.00 (99–100) – Excellent Performance

# Categorization loop
for grade in df['MIDTERM GRADE']:
    if grade <= 74:
        midterm_range1.append(grade)
    elif 75 <= grade <= 77:
        midterm_range2.append(grade)
    elif 77 < grade <= 80:
        midterm_range3.append(grade)
    elif 80 < grade <= 83:
        midterm_range4.append(grade)
    elif 83 < grade <= 86:
        midterm_range5.append(grade)
    elif 86 < grade <= 89:
        midterm_range6.append(grade)
    elif 90 < grade <= 92:
        midterm_range7.append(grade)
    elif 93 < grade <= 95:
        midterm_range8.append(grade)
    elif 96 < grade <= 98:
        midterm_range9.append(grade)
    elif 98 < grade <= 100:
        midterm_range10.append(grade)
    
# Count students in each range
count2_range1 = len(midterm_range1) # Counting the number of students for this score range 
count2_range2 = len(midterm_range2) # Counting the number of students for this score range
count2_range3 = len(midterm_range3) # Counting the number of students for this score range 
count2_range4 = len(midterm_range4) # Counting the number of students for this score range 
count2_range5 = len(midterm_range5) # Counting the number of students for this score range
count2_range6 = len(midterm_range6) # Counting the number of students for this score range 
count2_range7 = len(midterm_range7) # Counting the number of students for this score range 
count2_range8 = len(midterm_range8) # Counting the number of students for this score range 
count2_range9 = len(midterm_range9) # Counting the number of students for this score range 
count2_range10 = len(midterm_range10) # Counting the number of students for this score range 

result1b = f"""With the total of {count2_range1} students in the grade range of 5.00 means a failure to meet the minimum requirements of the CLOs. 
This reflects major academic issues possibly due to lack of student motivation, ineffective learning strategies, curriculum misalignment, or faculty instructional gaps. 
A comprehensive review of teaching strategies, curriculum design, student engagement practices, and academic policies is necessary. 
Additional support systems like tutoring, counseling, and motivational workshops should be institutionalized."""

result2b = f"""Having a total of {count2_range2} students, grades of 75-77 (3.00) range mean students have barely passed and have significant deficiencies in achieving full CLOs. 
This raises concerns about student preparedness for more advanced courses. It is essential to revisit course prerequisites, strengthen early semester interventions, and provide compulsory remedial sessions for students in this range. 
Faculty development programs focusing on differentiated instruction are also suggested."""

result3b = f"""A total of {count2_range3} students obtained scores within the 78–80 (2.75) range are at a fair level, barely above passing thresholds. 
This reflects deficiencies in critical areas such as problem-solving, comprehension, and retention. Faculty should increase diagnostic assessments and offer remedial modules to prevent students from slipping into failing performance. 
Regular mentoring, personalized feedback, and smaller group tutorials could make significant improvements. """

result4b = f"""A total of {count2_range4} students is within the range of 81-83 (2.50). Hence, a grade of 2.50 indicates satisfactory performance, yet students are barely meeting expectations. This suggests minimal CLO attainment at acceptable levels. 
Faculty should enhance engagement strategies such as gamified quizzes, blended learning, and formative assessment to reinforce learning. It is critical to identify struggling students early and offer academic support interventions."""

result5b = f"""The {count2_range5} students within the range of 84-86 (2.25) show a low average performance, signaling potential struggles with understanding more complex topics or maintaining consistent study habits. This suggests that faculty must assess whether the content delivery pace is appropriate and whether differentiated instruction is necessary. 
Mid-course interventions, learning support programs, and targeted tutorials should be strengthened. """

result6b = f"""The {count2_range6} students within the range of 87-89 (2.00) reflects average attainment of the CLOs. Students demonstrate basic competency but are inconsistent in advanced applications. This suggests a need for reinforcing foundational concepts and providing additional support for problem-solving and communication skills. 
Faculty might integrate more scaffolded activities and provide feedback loops to build confidence and mastery. """

result7b = f"""With the total of {count2_range7} number of students obtained scores within the range of 90-92 (1.75) indicates a high average level of performance, meeting most expectations but with room for improving critical thinking and depth of understanding. 
This points toward a need for refining teaching methods to focus more on evaluation, synthesis, and creation stages of Bloom’s Taxonomy. 
More collaborative learning, debates, and reflective assignments are recommended. """

result8b = f"""A total of {count2_range8} students got scores within the range of 93-95 (1.50) showing superior mastery but may indicate slight inconsistencies in applying higher-order thinking. This suggests that while foundational knowledge is solid, application and integration in real-world settings can still be enhanced. 
Faculty should consider increasing authentic assessments (case studies, simulations) and strengthen analytical skills through complex problem-solving activities. """

result9b = f"""{count2_range9} students achieving scores within the range of 96-98 (1.25) reflect very superior performance, demonstrating deep understanding but with minimal learning gaps. This suggests strong alignment between assessment and instruction. To maximize their potential, activities promoting creativity, innovation, and leadership in technical fields should be encouraged. 
Faculty could introduce interdisciplinary projects or student-led seminars to deepen learning further. """

result10b = f"""The {count2_range10} students within the range of 99-100 (1.00) indicate excellent mastery of the Course Learning Outcomes (CLOs). This suggests that instructional strategies, curriculum design, and student engagement are highly effective. 
Minimal to no curriculum adjustments are needed. However, to further challenge students and sustain motivation, introducing research activities, industry immersion, or advanced project-based learning would be beneficial. 
Faculty may also explore mentorship programs for continuous excellence. """


# Finding which range has the highest number of students
highest_range2 = max(count2_range1, count2_range2, count2_range3, count2_range4, count2_range5, count2_range6, count2_range7, count2_range8, count2_range9, count2_range10)

# Determine the corresponding range
if highest_range2 == count2_range1:
    print(result1b)

elif highest_range2 == count2_range2:
    print(result2b)

elif highest_range2 == count2_range3:
    print(result3b)

elif highest_range2 == count2_range4:
    print(result4b)

elif highest_range2 == count2_range5:
    print(result5b)

elif highest_range2 == count2_range6:
    print(result6b)

elif highest_range2 == count2_range7:
    print(result7b)

elif highest_range2 == count2_range8:
    print(result8b)

elif highest_range2 == count2_range9:
    print(result9b)

elif highest_range2 == count2_range10:
    print(result10b)
# Out:
# With the total of 23 students in the grade range of 5.00 means a failure to meet the minimum requirements of the CLOs.
# This reflects major academic issues possibly due to lack of student motivation, ineffective learning strategies, curriculum misalignment, or faculty instructional gaps.
# A comprehensive review of teaching strategies, curriculum design, student engagement practices, and academic policies is necessary.
# Additional support systems like tutoring, counseling, and motivational workshops should be institutionalized.

# %% [markdown]
# ## Data Analytics for Final Grades

# %%
# Create lists for each range
final_range1 = [] # 5.00 (Below 75) – Failed
final_range2 = [] # 3.00 (75–77) – Passed
final_range3 = [] # 2.75 (78–80) – Fair Performance
final_range4 = [] # 2.50 (81–83) – Satisfactory Performance
final_range5 = [] # 2.25 (84–86) – Low Average Performance
final_range6 = [] # 2.00 (87–89) – Average Performance
final_range7 = [] # 1.75 (90–92) – High Average Performance
final_range8 = [] # 1.50 (93–95) – Superior Performance
final_range9 = [] # 1.25 (96–98) – Very Superior Performance
final_range10 = [] # 1.00 (99–100) – Excellent Performance

# Categorization loop
for grade in df['FINAL GRADE']:
    if grade <= 74:
        final_range1.append(grade)
    elif 75 <= grade <= 77:
        final_range2.append(grade)
    elif 77 < grade <= 80:
        final_range3.append(grade)
    elif 80 < grade <= 83:
        final_range4.append(grade)
    elif 83 < grade <= 86:
        final_range5.append(grade)
    elif 86 < grade <= 89:
        final_range6.append(grade)
    elif 90 < grade <= 92:
        final_range7.append(grade)
    elif 93 < grade <= 95:
        final_range8.append(grade)
    elif 96 < grade <= 98:
        final_range9.append(grade)
    elif 98 < grade <= 100:
        final_range10.append(grade)
    
# Count students in each range
count3_range1 = len(final_range1) # Counting the number of students for this score range 
count3_range2 = len(final_range2) # Counting the number of students for this score range
count3_range3 = len(final_range3) # Counting the number of students for this score range 
count3_range4 = len(final_range4) # Counting the number of students for this score range 
count3_range5 = len(final_range5) # Counting the number of students for this score range
count3_range6 = len(final_range6) # Counting the number of students for this score range 
count3_range7 = len(final_range7) # Counting the number of students for this score range 
count3_range8 = len(final_range8) # Counting the number of students for this score range 
count3_range9 = len(final_range9) # Counting the number of students for this score range 
count3_range10 = len(final_range10) # Counting the number of students for this score range 

result1c = f"""With the total of {count3_range1} students in the grade range of 5.00 means a failure to meet the minimum requirements of the CLOs. 
This reflects major academic issues possibly due to lack of student motivation, ineffective learning strategies, curriculum misalignment, or faculty instructional gaps. 
A comprehensive review of teaching strategies, curriculum design, student engagement practices, and academic policies is necessary. 
Additional support systems like tutoring, counseling, and motivational workshops should be institutionalized."""

result2c = f"""Having a total of {count3_range2} students, grades of 75-77 (3.00) range mean students have barely passed and have significant deficiencies in achieving full CLOs. 
This raises concerns about student preparedness for more advanced courses. It is essential to revisit course prerequisites, strengthen early semester interventions, and provide compulsory remedial sessions for students in this range. 
Faculty development programs focusing on differentiated instruction are also suggested."""

result3c = f"""A total of {count3_range3} students obtained scores within the 78–80 (2.75) range are at a fair level, barely above passing thresholds. 
This reflects deficiencies in critical areas such as problem-solving, comprehension, and retention. Faculty should increase diagnostic assessments and offer remedial modules to prevent students from slipping into failing performance. 
Regular mentoring, personalized feedback, and smaller group tutorials could make significant improvements. """

result4c = f"""A total of {count3_range4} students is within the range of 81-83 (2.50). Hence, a grade of 2.50 indicates satisfactory performance, yet students are barely meeting expectations. This suggests minimal CLO attainment at acceptable levels. 
Faculty should enhance engagement strategies such as gamified quizzes, blended learning, and formative assessment to reinforce learning. It is critical to identify struggling students early and offer academic support interventions."""

result5c = f"""The {count3_range5} students within the range of 84-86 (2.25) show a low average performance, signaling potential struggles with understanding more complex topics or maintaining consistent study habits. This suggests that faculty must assess whether the content delivery pace is appropriate and whether differentiated instruction is necessary. 
Mid-course interventions, learning support programs, and targeted tutorials should be strengthened. """

result6c = f"""The {count3_range6} students within the range of 87-89 (2.00) reflects average attainment of the CLOs. Students demonstrate basic competency but are inconsistent in advanced applications. This suggests a need for reinforcing foundational concepts and providing additional support for problem-solving and communication skills. 
Faculty might integrate more scaffolded activities and provide feedback loops to build confidence and mastery. """

result7c = f"""With the total of {count3_range7} number of students obtained scores within the range of 90-92 (1.75) indicates a high average level of performance, meeting most expectations but with room for improving critical thinking and depth of understanding. 
This points toward a need for refining teaching methods to focus more on evaluation, synthesis, and creation stages of Bloom’s Taxonomy. 
More collaborative learning, debates, and reflective assignments are recommended. """

result8c = f"""A total of {count3_range8} students got scores within the range of 93-95 (1.50) showing superior mastery but may indicate slight inconsistencies in applying higher-order thinking. This suggests that while foundational knowledge is solid, application and integration in real-world settings can still be enhanced. 
Faculty should consider increasing authentic assessments (case studies, simulations) and strengthen analytical skills through complex problem-solving activities. """

result9c = f"""{count3_range9} students achieving scores within the range of 96-98 (1.25) reflect very superior performance, demonstrating deep understanding but with minimal learning gaps. This suggests strong alignment between assessment and instruction. To maximize their potential, activities promoting creativity, innovation, and leadership in technical fields should be encouraged. 
Faculty could introduce interdisciplinary projects or student-led seminars to deepen learning further. """

result10c = f"""The {count3_range10} students within the range of 99-100 (1.00) indicate excellent mastery of the Course Learning Outcomes (CLOs). This suggests that instructional strategies, curriculum design, and student engagement are highly effective. 
Minimal to no curriculum adjustments are needed. However, to further challenge students and sustain motivation, introducing research activities, industry immersion, or advanced project-based learning would be beneficial. 
Faculty may also explore mentorship programs for continuous excellence. """


# Finding which range has the highest number of students
highest_range3 = max(count3_range1, count3_range2, count3_range3, count3_range4, count3_range5, count3_range6, count3_range7, count3_range8, count3_range9, count3_range10)

# Determine the corresponding range
if highest_range3 == count3_range1:
    print(result1c)

elif highest_range3 == count3_range2:
    print(result2c)

elif highest_range3 == count3_range3:
    print(result3c)

elif highest_range2 == count3_range4:
    print(result4c)

elif highest_range2 == count2_range5:
    print(result5c)

elif highest_range2 == count2_range6:
    print(result6c)

elif highest_range2 == count2_range7:
    print(result7c)

elif highest_range2 == count2_range8:
    print(result8c)

elif highest_range2 == count2_range9:
    print(result9c)

elif highest_range2 == count2_range10:
    print(result10c)
# Out:
# With the total of 21 students in the grade range of 5.00 means a failure to meet the minimum requirements of the CLOs.
# This reflects major academic issues possibly due to lack of student motivation, ineffective learning strategies, curriculum misalignment, or faculty instructional gaps.
# A comprehensive review of teaching strategies, curriculum design, student engagement practices, and academic policies is necessary.
# Additional support systems like tutoring, counseling, and motivational workshops should be institutionalized.
